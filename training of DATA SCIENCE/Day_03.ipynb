# %%
lst = []
dic1 = {
    "virat":13,
    "rohit":14,
    "dhoni":12
}
dic2 = {
    "bumrah":2,
    "japreet":3,
    "bhuvi":1
}
lst.append(dic1)
lst.append(dic2)

print(lst)
print(dic1["virat"])
print(dic2["bhuvi"])
# Out:
# [{'virat': 13, 'rohit': 14, 'dhoni': 12}, {'bumrah': 2, 'japreet': 3, 'bhuvi': 1}]
# 13
# 1

# %%
lst=list()
dic1={}
dic2={}
choice=input("TYPE Y TO CONTINUE AND N TO EXIT :")
while choice == "y":
    batsman_name=input("ENTER THE BATSMAN NAME :")
    score=int(input("ENTER THE SCORE OF THE BATSMAN :"))
    dic1[batsman_name]=score

    bowler_name=input("ENTER THE BOWLER NAME :")
    wickets = int(input("ENETER THE NUMBER OF WICKETS :"))
    dic2[bowler_name]=wickets

    choice=input("TYPE Y TO CONTINUE AND N TO EXIT :")

lst.append(dic1)
lst.append(dic2)

print(lst)
# Out:
# TYPE Y TO CONTINUE AND N TO EXIT : y
# ENTER THE BATSMAN NAME : virat
# ENTER THE SCORE OF THE BATSMAN : 31
# ENTER THE BOWLER NAME : bumrah
# ENETER THE NUMBER OF WICKETS : 2
# TYPE Y TO CONTINUE AND N TO EXIT : y
# ENTER THE BATSMAN NAME : dhoni
# ENTER THE SCORE OF THE BATSMAN : 34
# ENTER THE BOWLER NAME : bhuvi
# ENETER THE NUMBER OF WICKETS : 1
# TYPE Y TO CONTINUE AND N TO EXIT : y
# ENTER THE BATSMAN NAME : rohit
# ENTER THE SCORE OF THE BATSMAN : 47
# ENTER THE BOWLER NAME : ishant
# ENETER THE NUMBER OF WICKETS : 5
# TYPE Y TO CONTINUE AND N TO EXIT : n
# [{'virat': 31, 'dhoni': 34, 'rohit': 47}, {'bumrah': 2, 'bhuvi': 1, 'ishant': 5}]
