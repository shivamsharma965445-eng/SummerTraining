# %%
pip install panda
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7293 sha256=6201312d726e50f7921d633fe2c06e7d4f12b5ac8ddbbc2d26616386dd8b5d55
#   Stored in directory: c:\users\shivam\appdata\local\pip\cache\wheels\53\7c\f7\d3267739bc9dfdfc43724391337c9955e7d5b5830888d735e3
# Successfully built panda
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.DataFrame({"NAME":["Shivam","Ishnat","Mayank","Harsh"],"MARKS":[99,92,98,87]})
df
# Out:
#      NAME  MARKS
# 0  Shivam     99
# 1  Ishnat     92
# 2  Mayank     98
# 3   Harsh     87

# %%
df.duplicated("NAME")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool
