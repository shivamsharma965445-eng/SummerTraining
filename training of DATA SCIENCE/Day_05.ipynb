# %%
# %pip install numpy
import numpy as np
# Out:
# Requirement already satisfied: numpy in c:\users\shivam\anaconda3\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a*b)
print(a**b)
print(a%b)
# Out:
# [5 7 9]
# [-3 -3 -3]
# [0.25 0.4  0.5 ]
# [0 0 0]
# [ 4 10 18]
# [  1  32 729]
# [1 2 3]

# %%
c=np.array([[1,2,3],[2,3,4]])
d=np.array([[1,2,3],[4,5,6]])

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
np.dot(a,np.transpose(b))
# Out:
# [5 7 9]
# [-3 -3 -3]
# [ 4 10 18]
# [0.25 0.4  0.5 ]
# [0 0 0]
# [1 2 3]
# [  1  32 729]
# np.int64(32)

# %%
a = np.array([[10,20,30],[5,10,15]])

print(np.min(a))
print(np.sum(a))
print(np.max(a))
print(np.sum(a, axis=0))
print(np.sum(a, axis=1))
# Out:
# 5
# 90
# 30
# [15 30 45]
# [60 30]
