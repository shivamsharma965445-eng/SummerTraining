# %%
lst = list("hello")
lst.remove('o')
print(lst)
# Out:
# ['h', 'e', 'l', 'l']

# %%
for i in range(10):
    lst= list(input("ENTER AN ELEMENT OF THE LIST :"))
print(lst)
# Out:
# ENTER AN ELEMENT OF THE LIST : 67
# ENTER AN ELEMENT OF THE LIST : drd
# ENTER AN ELEMENT OF THE LIST : 89
# ENTER AN ELEMENT OF THE LIST : rtdr
# ENTER AN ELEMENT OF THE LIST : ftyc
# ENTER AN ELEMENT OF THE LIST : 9097.98
# ENTER AN ELEMENT OF THE LIST : gtty
# ENTER AN ELEMENT OF THE LIST : 333
# ENTER AN ELEMENT OF THE LIST : ff
# ENTER AN ELEMENT OF THE LIST : 4
# ['4']

# %%
lst= list(input("ENTER AN ELEMENT OF THE LIST :"))
print(lst)
# Out:
# ENTER AN ELEMENT OF THE LIST : 67
# ['6', '7']

# %%
lst=list()
for i in range(5):
    el = input("ENTER AN ELEMENT OF THE LIST :")
    lst.append(el)

print(lst)
# Out:
# ENTER AN ELEMENT OF THE LIST : 56
# ENTER AN ELEMENT OF THE LIST : ggf
# ENTER AN ELEMENT OF THE LIST : 886.97
# ENTER AN ELEMENT OF THE LIST : fdy
# ENTER AN ELEMENT OF THE LIST : gf788
# ['56', 'ggf', '886.97', 'fdy', 'gf788']

# %%
a = {
    "shivam":100,
    "harshita":92,
    "gitanshu":97,
    "keshav":55}

print(a["harshita"])
# Out:
# 92

# %%
a= {
    1:"Shivam",
    2:"Gitanshu",
    3:"Harsh",
    4:"neeta"
}

print(a)
a[0]="geeta"
print(a)
print(a[3])
print(a.get(3))#it gives none if the value is not exists but a[3] gives an error .
# Out:
# {1: 'Shivam', 2: 'Gitanshu', 3: 'Harsh', 4: 'neeta'}
# {1: 'Shivam', 2: 'Gitanshu', 3: 'Harsh', 4: 'neeta', 0: 'geeta'}
# Harsh
# Harsh
